# %% [markdown]
# # Advanced Calculus: Written HW 1

# %% [markdown]
# # P2

# %%
F = piecewise([((-pi,0), 0), ((0,pi), 2)], var=x); F
plot(F, (-pi, pi))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
F2 =1 + 4*sin(1*x)/(1*pi)
plot(F2, (-pi, pi))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
F4 = 1 + 4*sin(1*x)/(1*pi) + 4*sin(3*x)/(3*pi)
plot(F4, (-pi, pi))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
F6 = 1 + 4*sin(1*x)/(1*pi) + 4*sin(3*x)/(3*pi) + 4*sin(5*x)/(5*pi)
plot(F6, (-pi, pi))
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [markdown]
# # P3

# %%
g = .5 - 4*cos(pi*x)/(pi)^2 - 4*cos(3*pi*x)/(3*pi)^2 - 4*cos(5*pi*x)/(5*pi)^2 - 4*cos(5*pi*x)/(5*pi)^2 
plot(g, (-4,4))
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [markdown]
# # P4

# %%
h = 4*sin(1*pi*x/2)/(1*pi) + 4*sin(2*pi*x/2)/(2*pi) + 4*sin(3*pi*x/2)/(3*pi) + 4*sin(4*pi*x/2)/(4*pi) \
+ 4*sin(5*pi*x/2)/(5*pi) + 4*sin(6*pi*x/2)/(6*pi)
plot(h, (-8,8))
# Out:
# Graphics object consisting of 1 graphics primitive
